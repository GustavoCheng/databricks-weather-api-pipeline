# %%
# %sql
SELECT *
FROM portfolio.weather_api_pipeline.gold_monthly_weather_sao_paulo
ORDER BY year, month;

# %%
# %sql
SELECT
  year,
  month,
  month_name,
  city,
  avg_temperature_celsius,
  highest_temperature_celsius
FROM portfolio.weather_api_pipeline.gold_monthly_weather_sao_paulo
ORDER BY avg_temperature_celsius DESC
LIMIT 5;

# %%
# %sql
SELECT
  year,
  month,
  month_name,
  city,
  total_precipitation_mm,
  rainy_days,
  rainy_days_rate
FROM portfolio.weather_api_pipeline.gold_monthly_weather_sao_paulo
ORDER BY total_precipitation_mm DESC
LIMIT 5;

# %%
# %sql
SELECT
  year,
  month,
  month_name,
  city,
  total_precipitation_mm,
  rainy_days,
  rainy_days_rate
FROM portfolio.weather_api_pipeline.gold_monthly_weather_sao_paulo
ORDER BY total_precipitation_mm ASC
LIMIT 5;

# %%
# %sql
SELECT
  CONCAT(CAST(year AS STRING), '-', LPAD(CAST(month AS STRING), 2, '0')) AS year_month,
  city,
  avg_temperature_celsius,
  total_precipitation_mm,
  rainy_days_rate,
  avg_windspeed_max_kmh
FROM portfolio.weather_api_pipeline.gold_monthly_weather_sao_paulo
ORDER BY year, month;
